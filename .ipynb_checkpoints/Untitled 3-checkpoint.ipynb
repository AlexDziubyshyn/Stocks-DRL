# %%
import numpy as np
import pandas as pd
import time
import matplotlib.pyplot as plt
import seaborn as sns
import random
sns.set()

# %%
import pkg_resources
import types


def get_imports():
    for name, val in globals().items():
        if isinstance(val, types.ModuleType):
            name = val.__name__.split('.')[0]
        elif isinstance(val, type):
            name = val.__module__.split('.')[0]
        poorly_named_packages = {'PIL': 'Pillow', 'sklearn': 'scikit-learn'}
        if name in poorly_named_packages.keys():
            name = poorly_named_packages[name]
        yield name


imports = list(set(get_imports()))
requirements = []
for m in pkg_resources.working_set:
    if m.project_name in imports and m.project_name != 'pip':
        requirements.append((m.project_name, m.version))

for r in requirements:
    print('{}=={}'.format(*r))
# Out:
# matplotlib==1.5.1
# pandas==0.19.2
# numpy==1.11.3
# seaborn==0.7.1
# azureml==0.2.7

# %%
from azureml import Workspace

ws = Workspace()
ds = ws.datasets['GOOG.csv']
df = ds.to_dataframe()

df = df[df.Date >= '2018-01-01']

# %%
class Deep_Evolution_Strategy:

    inputs = None

    def __init__(
        self, weights, reward_function, population_size, sigma, learning_rate
    ):
        self.weights = weights
        self.reward_function = reward_function
        self.population_size = population_size
        self.sigma = sigma
        self.learning_rate = learning_rate

    def _get_weight_from_population(self, weights, population):
        weights_population = []
        for index, i in enumerate(population):
            jittered = self.sigma * i
            weights_population.append(weights[index] + jittered)
        return weights_population

    def get_weights(self):
        return self.weights

    def train(self, epoch = 100, print_every = 1):
        lasttime = time.time()
        for i in range(epoch):
            population = []
            rewards = np.zeros(self.population_size)
            for k in range(self.population_size):
                x = []
                for w in self.weights:
                    x.append(np.random.randn(*w.shape))
                population.append(x)
            for k in range(self.population_size):
                weights_population = self._get_weight_from_population(
                    self.weights, population[k]
                )
                rewards[k] = self.reward_function(weights_population)
            rewards = (rewards - np.mean(rewards)) / (np.std(rewards) + 1e-7)
            for index, w in enumerate(self.weights):
                A = np.array([p[index] for p in population])
                self.weights[index] = (
                    w
                    + self.learning_rate
                    / (self.population_size * self.sigma)
                    * np.dot(A.T, rewards).T
                )
            if (i + 1) % print_every == 0:
                print(
                    'iter %d. reward: %f'
                    % (i + 1, self.reward_function(self.weights))
                )
        print('time taken to train:', time.time() - lasttime, 'seconds')

class Model:
    def __init__(self, input_size, layer_size, output_size):
        self.weights = [
            np.random.randn(input_size, layer_size),
            np.random.randn(layer_size, output_size),
            np.random.randn(1, layer_size),
        ]

    def predict(self, inputs):
        feed = np.dot(inputs, self.weights[0]) + self.weights[-1]
        decision = np.dot(feed, self.weights[1])
        return decision

    def get_weights(self):
        return self.weights

    def set_weights(self, weights):
        self.weights = weights

# %%
class Agent:

    POPULATION_SIZE = 15
    SIGMA = 0.1
    LEARNING_RATE = 0.03

    def __init__(self, model, window_size, trend, skip, initial_money):
        self.model = model
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        self.initial_money = initial_money
        self.es = Deep_Evolution_Strategy(
            self.model.get_weights(),
            self.get_reward,
            self.POPULATION_SIZE,
            self.SIGMA,
            self.LEARNING_RATE,
        )

    def act(self, sequence):
        decision = self.model.predict(np.array(sequence))
        return np.argmax(decision[0])
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array([res])
    
    def get_reward(self, weights):
        initial_money = self.initial_money
        starting_money = initial_money
        self.model.weights = weights
        state = self.get_state(0)
        inventory = []
        quantity = 0
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self.act(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and starting_money >= self.trend[t]:
                inventory.append(self.trend[t])
                starting_money -= close[t]
                
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                starting_money += self.trend[t]

            state = next_state
        return ((starting_money - initial_money) / initial_money) * 100

    def fit(self, iterations, checkpoint):
        self.es.train(iterations, print_every = checkpoint)

    def buy(self):
        initial_money = self.initial_money
        state = self.get_state(0)
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self.act(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t]:
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total inventory %f, total balance %f'% (t, self.trend[t], len(inventory), initial_money))
            
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f,  total inventory %f, investment %f %%, total balance %f,'
                    % (t, close[t], len(inventory), invest, initial_money)
                )
            state = next_state
            

        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest

# %%
close = df.Close.values.tolist()
window_size = 30
skip = 2
initial_money = 3000

model = Model(input_size = window_size, layer_size = 500, output_size = 3)
agent = Agent(model = model, 
              window_size = window_size,
              trend = close,
              skip = skip,
              initial_money = initial_money)
agent.fit(iterations = 500, checkpoint = 10)
# Out:
# iter 10. reward: 31.376988
# iter 20. reward: 42.092332
# iter 30. reward: 44.799001
# iter 40. reward: 41.676996
# iter 50. reward: 44.146667
# iter 60. reward: 48.851994
# iter 70. reward: 48.847312
# iter 80. reward: 55.176322
# iter 90. reward: 51.575330
# iter 100. reward: 54.502327
# iter 110. reward: 55.973336
# iter 120. reward: 54.158993
# iter 130. reward: 57.207989
# iter 140. reward: 55.298987
# iter 150. reward: 63.039323
# iter 160. reward: 63.683653
# iter 170. reward: 62.530994
# iter 180. reward: 57.571322
# iter 190. reward: 65.698989
# iter 200. reward: 65.156657
# iter 210. reward: 60.907992
# iter 220. reward: 64.309330
# iter 230. reward: 66.366329
# iter 240. reward: 70.023328
# iter 250. reward: 68.434666
# iter 260. reward: 70.286668
# iter 270. reward: 70.250002
# iter 280. reward: 70.976996
# iter 290. reward: 70.554995
# iter 300. reward: 69.501328
# iter 310. reward: 68.357664
# iter 320. reward: 70.904338
# iter 330. reward: 72.944999
# iter 340. reward: 72.161332
# iter 350. reward: 71.538664
# iter 360. reward: 71.529000
# iter 370. reward: 71.909330
# iter 380. reward: 74.216992
# iter 390. reward: 74.216992
# iter 400. reward: 74.552328
# iter 410. reward: 72.045996
# iter 420. reward: 74.887002
# iter 430. reward: 75.676996
# iter 440. reward: 76.332326
# iter 450. reward: 76.903990
# iter 460. reward: 77.366665
# iter 470. reward: 77.976662
# iter 480. reward: 77.221991
# iter 490. reward: 76.784662
# iter 500. reward: 75.985999
# time taken to train: 94.35450387001038 seconds

# %%
states_buy, states_sell, total_gains, invest = agent.buy()
# Out:
# day 0: buy 1 unit at price 1065.000000, total inventory 1.000000, total balance 1935.000000
# day 6: buy 1 unit at price 1102.609985, total inventory 2.000000, total balance 832.390015
# day 8, sell 1 unit at price 1122.260010,  total inventory 1.000000, investment 5.376527 %, total balance 1954.650025,
# day 12: buy 1 unit at price 1137.510010, total inventory 2.000000, total balance 817.140015
# day 14, sell 1 unit at price 1169.969971,  total inventory 1.000000, investment 6.109140 %, total balance 1987.109986,
# day 16: buy 1 unit at price 1170.369995, total inventory 2.000000, total balance 816.739991
# day 18, sell 1 unit at price 1175.579956,  total inventory 1.000000, investment 3.346779 %, total balance 1992.319947,
# day 20, sell 1 unit at price 1169.939941,  total inventory 0.000000, investment -0.036745 %, total balance 3162.259888,
# day 24: buy 1 unit at price 1080.599976, total inventory 1.000000, total balance 2081.659912
# day 28: buy 1 unit at price 1051.939941, total inventory 2.000000, total balance 1029.719971
# day 34, sell 1 unit at price 1111.339966,  total inventory 1.000000, investment 2.844715 %, total balance 2141.059937,
# day 38, sell 1 unit at price 1118.290039,  total inventory 0.000000, investment 6.307404 %, total balance 3259.349976,
# day 40: buy 1 unit at price 1069.520020, total inventory 1.000000, total balance 2189.829956
# day 42: buy 1 unit at price 1090.930054, total inventory 2.000000, total balance 1098.899902
# day 46, sell 1 unit at price 1160.040039,  total inventory 1.000000, investment 8.463611 %, total balance 2258.939941,
# day 50, sell 1 unit at price 1149.579956,  total inventory 0.000000, investment 5.376138 %, total balance 3408.519897,
# day 58: buy 1 unit at price 1005.099976, total inventory 1.000000, total balance 2403.419921
# day 60, sell 1 unit at price 1031.790039,  total inventory 0.000000, investment 2.655463 %, total balance 3435.209960,
# day 66: buy 1 unit at price 1015.450012, total inventory 1.000000, total balance 2419.759948
# day 68: buy 1 unit at price 1019.969971, total inventory 2.000000, total balance 1399.789977
# day 70, sell 1 unit at price 1029.270020,  total inventory 1.000000, investment 1.360974 %, total balance 2429.059997,
# day 74, sell 1 unit at price 1087.699951,  total inventory 0.000000, investment 6.640390 %, total balance 3516.759948,
# day 78: buy 1 unit at price 1021.179993, total inventory 1.000000, total balance 2495.579955
# day 82: buy 1 unit at price 1037.310059, total inventory 2.000000, total balance 1458.269896
# day 84: buy 1 unit at price 1023.719971, total inventory 3.000000, total balance 434.549925
# day 92, sell 1 unit at price 1079.229980,  total inventory 2.000000, investment 5.684599 %, total balance 1513.779905,
# day 94: buy 1 unit at price 1078.589966, total inventory 3.000000, total balance 435.189939
# day 98, sell 1 unit at price 1079.689941,  total inventory 2.000000, investment 4.085556 %, total balance 1514.879880,
# day 100: buy 1 unit at price 1075.660034, total inventory 3.000000, total balance 439.219846
# day 104, sell 1 unit at price 1119.500000,  total inventory 2.000000, investment 9.356077 %, total balance 1558.719846,
# day 108: buy 1 unit at price 1123.859985, total inventory 3.000000, total balance 434.859861
# day 114, sell 1 unit at price 1152.260010,  total inventory 2.000000, investment 6.830218 %, total balance 1587.119871,
# day 118: buy 1 unit at price 1157.660034, total inventory 3.000000, total balance 429.459837
# day 120, sell 1 unit at price 1124.810059,  total inventory 2.000000, investment 4.569290 %, total balance 1554.269896,
# day 126: buy 1 unit at price 1102.890015, total inventory 3.000000, total balance 451.379881
# day 128, sell 1 unit at price 1140.170044,  total inventory 2.000000, investment 1.451254 %, total balance 1591.549925,
# day 134, sell 1 unit at price 1183.859985,  total inventory 1.000000, investment 2.263182 %, total balance 2775.409910,
# day 136: buy 1 unit at price 1195.880005, total inventory 2.000000, total balance 1579.529905
# day 138: buy 1 unit at price 1184.910034, total inventory 3.000000, total balance 394.619871
# day 140, sell 1 unit at price 1248.079956,  total inventory 2.000000, investment 13.164499 %, total balance 1642.699827,
# day 142, sell 1 unit at price 1268.329956,  total inventory 1.000000, investment 6.058296 %, total balance 2911.029783,
# day 144: buy 1 unit at price 1219.739990, total inventory 2.000000, total balance 1691.289793
# day 146, sell 1 unit at price 1220.010010,  total inventory 1.000000, investment 2.962248 %, total balance 2911.299803,
# day 150, sell 1 unit at price 1242.219971,  total inventory 0.000000, investment 1.843014 %, total balance 4153.519774,
# day 154: buy 1 unit at price 1235.010010, total inventory 1.000000, total balance 2918.509764
# day 156: buy 1 unit at price 1214.380005, total inventory 2.000000, total balance 1704.129759
# day 158, sell 1 unit at price 1200.959961,  total inventory 1.000000, investment -2.757067 %, total balance 2905.089720,
# day 162: buy 1 unit at price 1205.380005, total inventory 2.000000, total balance 1699.709715
# day 164, sell 1 unit at price 1241.819946,  total inventory 1.000000, investment 2.259584 %, total balance 2941.529661,
# day 166, sell 1 unit at price 1249.300049,  total inventory 0.000000, investment 3.643668 %, total balance 4190.829710,
# day 174: buy 1 unit at price 1177.359985, total inventory 1.000000, total balance 3013.469725
# day 176, sell 1 unit at price 1175.329956,  total inventory 0.000000, investment -0.172422 %, total balance 4188.799681,
# day 188: buy 1 unit at price 1195.310059, total inventory 1.000000, total balance 2993.489622
# day 190, sell 1 unit at price 1202.949951,  total inventory 0.000000, investment 0.639156 %, total balance 4196.439573,
# day 196: buy 1 unit at price 1079.319946, total inventory 1.000000, total balance 3117.119627
# day 198, sell 1 unit at price 1092.250000,  total inventory 0.000000, investment 1.197982 %, total balance 4209.369627,
# day 208: buy 1 unit at price 1020.080017, total inventory 1.000000, total balance 3189.289610
# day 210, sell 1 unit at price 1076.770020,  total inventory 0.000000, investment 5.557407 %, total balance 4266.059630,
# day 214: buy 1 unit at price 1055.810059, total inventory 1.000000, total balance 3210.249571
# day 216, sell 1 unit at price 1082.400024,  total inventory 0.000000, investment 2.518442 %, total balance 4292.649595,
# day 218: buy 1 unit at price 1038.630005, total inventory 1.000000, total balance 3254.019590
# day 220, sell 1 unit at price 1043.660034,  total inventory 0.000000, investment 0.484295 %, total balance 4297.679624,
# day 224: buy 1 unit at price 1025.760010, total inventory 1.000000, total balance 3271.919614
# day 226: buy 1 unit at price 1023.880005, total inventory 2.000000, total balance 2248.039609
# day 228, sell 1 unit at price 1044.410034,  total inventory 1.000000, investment 1.818166 %, total balance 3292.449643,
# day 232, sell 1 unit at price 1106.430054,  total inventory 0.000000, investment 8.062473 %, total balance 4398.879697,
# day 236: buy 1 unit at price 1039.550049, total inventory 1.000000, total balance 3359.329648
# day 240, sell 1 unit at price 1042.099976,  total inventory 0.000000, investment 0.245291 %, total balance 4401.429624,
# day 242: buy 1 unit at price 1028.709961, total inventory 1.000000, total balance 3372.719663
# day 244: buy 1 unit at price 1009.409973, total inventory 2.000000, total balance 2363.309690
# day 246: buy 1 unit at price 976.219971, total inventory 3.000000, total balance 1387.089719
# day 250: buy 1 unit at price 1035.609985, total inventory 4.000000, total balance 351.479734
# day 254, sell 1 unit at price 1068.390015,  total inventory 3.000000, investment 3.857264 %, total balance 1419.869749,
# day 258: buy 1 unit at price 1057.189941, total inventory 4.000000, total balance 362.679808
# day 260, sell 1 unit at price 1077.150024,  total inventory 3.000000, investment 6.710856 %, total balance 1439.829832,
# day 262: buy 1 unit at price 1089.900024, total inventory 4.000000, total balance 349.929808
# day 264, sell 1 unit at price 1070.520020,  total inventory 3.000000, investment 9.659713 %, total balance 1420.449828,
# day 268: buy 1 unit at price 1070.079956, total inventory 4.000000, total balance 350.369872
# day 272, sell 1 unit at price 1110.750000,  total inventory 3.000000, investment 7.255629 %, total balance 1461.119872,
# day 276: buy 1 unit at price 1098.709961, total inventory 4.000000, total balance 362.409911
# day 278, sell 1 unit at price 1095.010010,  total inventory 3.000000, investment 3.577415 %, total balance 1457.419921,
# day 282: buy 1 unit at price 1113.650024, total inventory 4.000000, total balance 343.769897
# day 284, sell 1 unit at price 1113.800049,  total inventory 3.000000, investment 2.192864 %, total balance 1457.569946,
# day 286: buy 1 unit at price 1110.369995, total inventory 4.000000, total balance 347.199951
# day 296, sell 1 unit at price 1142.319946,  total inventory 3.000000, investment 6.750896 %, total balance 1489.519897,
# day 300: buy 1 unit at price 1185.550049, total inventory 4.000000, total balance 303.969848
# day 304, sell 1 unit at price 1223.969971,  total inventory 3.000000, investment 11.400644 %, total balance 1527.939819,
# day 308, sell 1 unit at price 1184.619995,  total inventory 2.000000, investment 6.372736 %, total balance 2712.559814,
# day 312: buy 1 unit at price 1194.430054, total inventory 3.000000, total balance 1518.129760
# day 314, sell 1 unit at price 1205.920044,  total inventory 2.000000, investment 8.605244 %, total balance 2724.049804,
# day 316, sell 1 unit at price 1207.150024,  total inventory 1.000000, investment 1.821937 %, total balance 3931.199828,
# day 318: buy 1 unit at price 1197.250000, total inventory 2.000000, total balance 2733.949828
# day 322, sell 1 unit at price 1221.099976,  total inventory 1.000000, investment 2.232858 %, total balance 3955.049804,
# day 326: buy 1 unit at price 1248.839966, total inventory 2.000000, total balance 2706.209838
# day 328, sell 1 unit at price 1256.000000,  total inventory 1.000000, investment 4.907079 %, total balance 3962.209838,
# day 330, sell 1 unit at price 1272.180054,  total inventory 0.000000, investment 1.868941 %, total balance 5234.389892,
# day 334: buy 1 unit at price 1162.609985, total inventory 1.000000, total balance 4071.779907
# day 338, sell 1 unit at price 1166.270020,  total inventory 0.000000, investment 0.314812 %, total balance 5238.049927,
# day 342: buy 1 unit at price 1120.439941, total inventory 1.000000, total balance 4117.609986
# day 344, sell 1 unit at price 1178.979980,  total inventory 0.000000, investment 5.224737 %, total balance 5296.589966,
# day 350: buy 1 unit at price 1133.469971, total inventory 1.000000, total balance 4163.119995
# day 352, sell 1 unit at price 1116.459961,  total inventory 0.000000, investment -1.500702 %, total balance 5279.579956,

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()
