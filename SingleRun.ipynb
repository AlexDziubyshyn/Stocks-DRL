# %%
import numpy as np
import pandas as pd
import time
import matplotlib.pyplot as plt
import seaborn as sns
import random
sns.set()

# %%
import pkg_resources
import types


def get_imports():
    for name, val in globals().items():
        if isinstance(val, types.ModuleType):
            name = val.__name__.split('.')[0]
        elif isinstance(val, type):
            name = val.__module__.split('.')[0]
        poorly_named_packages = {'PIL': 'Pillow', 'sklearn': 'scikit-learn'}
        if name in poorly_named_packages.keys():
            name = poorly_named_packages[name]
        yield name


imports = list(set(get_imports()))
requirements = []
for m in pkg_resources.working_set:
    if m.project_name in imports and m.project_name != 'pip':
        requirements.append((m.project_name, m.version))

for r in requirements:
    print('{}=={}'.format(*r))
# Out:
# seaborn==0.9.0
# pandas==0.23.4
# numpy==1.16.4
# matplotlib==2.2.3

# %%
class Deep_Evolution_Strategy:

    inputs = None

    def __init__(
        self, weights, reward_function, population_size, sigma, learning_rate
    ):
        self.weights = weights
        self.reward_function = reward_function
        self.population_size = population_size
        self.sigma = sigma
        self.learning_rate = learning_rate

    def _get_weight_from_population(self, weights, population):
        weights_population = []
        for index, i in enumerate(population):
            jittered = self.sigma * i
            weights_population.append(weights[index] + jittered)
        return weights_population

    def get_weights(self):
        return self.weights

    def train(self, epoch = 100, print_every = 1):
        lasttime = time.time()
        for i in range(epoch):
            population = []
            rewards = np.zeros(self.population_size)
            for k in range(self.population_size):
                x = []
                for w in self.weights:
                    x.append(np.random.randn(*w.shape))
                population.append(x)
            for k in range(self.population_size):
                weights_population = self._get_weight_from_population(
                    self.weights, population[k]
                )
                rewards[k] = self.reward_function(weights_population)
            rewards = (rewards - np.mean(rewards)) / (np.std(rewards) + 1e-7)
            for index, w in enumerate(self.weights):
                A = np.array([p[index] for p in population])
                self.weights[index] = (
                    w
                    + self.learning_rate
                    / (self.population_size * self.sigma)
                    * np.dot(A.T, rewards).T
                )
            if (i + 1) % print_every == 0:
                print(
                    'iter %d. reward: %f'
                    % (i + 1, self.reward_function(self.weights))
                )
        print('time taken to train:', time.time() - lasttime, 'seconds')

class Model:
    def __init__(self, input_size, layer_size, output_size):
        self.weights = [
            np.random.randn(input_size, layer_size),
            np.random.randn(layer_size, output_size),
            np.random.randn(1, layer_size),
        ]

    def predict(self, inputs):
        feed = np.dot(inputs, self.weights[0]) + self.weights[-1]
        decision = np.dot(feed, self.weights[1])
        return decision

    def get_weights(self):
        return self.weights

    def set_weights(self, weights):
        self.weights = weights

# %%
class Agent:

    POPULATION_SIZE = 15
    SIGMA = 0.1
    LEARNING_RATE = 0.03

    def __init__(self, model, window_size, trend, skip, initial_money):
        self.model = model
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        self.initial_money = initial_money
        self.es = Deep_Evolution_Strategy(
            self.model.get_weights(),
            self.get_reward,
            self.POPULATION_SIZE,
            self.SIGMA,
            self.LEARNING_RATE,
        )

    def act(self, sequence):
        decision = self.model.predict(np.array(sequence))
        return np.argmax(decision[0])
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array([res])
    
    def get_reward(self, weights):
        initial_money = self.initial_money
        starting_money = initial_money
        self.model.weights = weights
        state = self.get_state(0)
        inventory = []
        quantity = 0
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self.act(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and starting_money >= self.trend[t]:
                inventory.append(self.trend[t])
                starting_money -= close[t]
                
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                starting_money += self.trend[t]

            state = next_state
        return ((starting_money - initial_money) / initial_money) * 100

    def fit(self, iterations, checkpoint):
        self.es.train(iterations, print_every = checkpoint)

    def buy(self):
        initial_money = self.initial_money
        state = self.get_state(0)
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self.act(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t]:
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total inventory %f, total balance %f'% (t, self.trend[t], len(inventory), initial_money))
            
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f,  total inventory %f, investment %f %%, total balance %f,'
                    % (t, close[t], len(inventory), invest, initial_money)
                )
            state = next_state
            

        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest

# %%
df = pd.read_csv('./data/AAPL_2.csv', header=0)
close = df.Close.values.tolist()
window_size = 30
skip = 2
initial_money = 2000

model = Model(input_size = window_size, layer_size = 500, output_size = 3)
agent = Agent(model = model, 
              window_size = window_size,
              trend = close,
              skip = skip,
              initial_money = initial_money)
agent.fit(iterations = 500, checkpoint = 10)
# Out:
# iter 10. reward: 2.719499
# iter 20. reward: 21.050003
# iter 30. reward: 28.609002
# iter 40. reward: 52.469005
# iter 50. reward: 51.848004
# iter 60. reward: 53.679003
# iter 70. reward: 56.851503
# iter 80. reward: 54.361002
# iter 90. reward: 60.052003
# iter 100. reward: 60.284505
# iter 110. reward: 63.800503
# iter 120. reward: 65.909003
# iter 130. reward: 65.857504
# iter 140. reward: 65.608504
# iter 150. reward: 75.536504
# iter 160. reward: 75.531502
# iter 170. reward: 68.639003
# iter 180. reward: 78.306004
# iter 190. reward: 77.050504
# iter 200. reward: 77.102001
# iter 210. reward: 75.916503
# iter 220. reward: 73.431001
# iter 230. reward: 76.192502
# iter 240. reward: 71.558003
# iter 250. reward: 73.350502
# iter 260. reward: 74.570500
# iter 270. reward: 74.623999
# iter 280. reward: 68.397000
# iter 290. reward: 81.781003
# iter 300. reward: 81.473003
# iter 310. reward: 80.931004
# iter 320. reward: 80.974004
# iter 330. reward: 83.194505
# iter 340. reward: 85.996504
# iter 350. reward: 85.731005
# iter 360. reward: 85.267504
# iter 370. reward: 84.041505
# iter 380. reward: 78.907504
# iter 390. reward: 84.194505
# iter 400. reward: 86.208504
# iter 410. reward: 84.873504
# iter 420. reward: 84.191504
# iter 430. reward: 88.495504
# iter 440. reward: 90.582504
# iter 450. reward: 90.532004
# iter 460. reward: 90.792004
# iter 470. reward: 91.503503
# iter 480. reward: 90.430003
# iter 490. reward: 88.625004
# iter 500. reward: 88.188003
# time taken to train: 63.08734393119812 seconds

# %%
states_buy, states_sell, total_gains, invest = agent.buy()
# Out:
# day 0: buy 1 unit at price 161.600006, total inventory 1.000000, total balance 1838.399994
# day 6: buy 1 unit at price 159.979996, total inventory 2.000000, total balance 1678.419998
# day 8: buy 1 unit at price 159.860001, total inventory 3.000000, total balance 1518.559997
# day 10: buy 1 unit at price 162.910004, total inventory 4.000000, total balance 1355.649993
# day 12: buy 1 unit at price 164.000000, total inventory 5.000000, total balance 1191.649993
# day 14, sell 1 unit at price 162.080002,  total inventory 4.000000, investment 0.297027 %, total balance 1353.729995,
# day 24, sell 1 unit at price 158.729996,  total inventory 3.000000, investment -0.781348 %, total balance 1512.459991,
# day 26: buy 1 unit at price 153.389999, total inventory 4.000000, total balance 1359.069992
# day 28: buy 1 unit at price 150.550003, total inventory 5.000000, total balance 1208.519989
# day 30: buy 1 unit at price 154.229996, total inventory 6.000000, total balance 1054.289993
# day 32: buy 1 unit at price 154.119995, total inventory 7.000000, total balance 900.169998
# day 34: buy 1 unit at price 154.479996, total inventory 8.000000, total balance 745.690002
# day 36: buy 1 unit at price 155.389999, total inventory 9.000000, total balance 590.300003
# day 38: buy 1 unit at price 155.839996, total inventory 10.000000, total balance 434.460007
# day 42: buy 1 unit at price 156.990005, total inventory 11.000000, total balance 277.470002
# day 50: buy 1 unit at price 156.410004, total inventory 12.000000, total balance 121.059998
# day 54, sell 1 unit at price 169.039993,  total inventory 11.000000, investment 5.742520 %, total balance 290.099991,
# day 58, sell 1 unit at price 174.250000,  total inventory 10.000000, investment 6.960896 %, total balance 464.349991,
# day 60, sell 1 unit at price 176.240005,  total inventory 9.000000, investment 7.463418 %, total balance 640.589996,
# day 62, sell 1 unit at price 174.669998,  total inventory 8.000000, investment 13.873133 %, total balance 815.259994,
# day 66, sell 1 unit at price 171.100006,  total inventory 7.000000, investment 13.649952 %, total balance 986.360000,
# day 70, sell 1 unit at price 174.960007,  total inventory 6.000000, investment 13.440972 %, total balance 1161.320007,
# day 72, sell 1 unit at price 174.089996,  total inventory 5.000000, investment 12.957437 %, total balance 1335.410003,
# day 74, sell 1 unit at price 169.479996,  total inventory 4.000000, investment 9.709995 %, total balance 1504.889999,
# day 76, sell 1 unit at price 171.050003,  total inventory 3.000000, investment 10.077871 %, total balance 1675.940002,
# day 78, sell 1 unit at price 169.639999,  total inventory 2.000000, investment 8.855238 %, total balance 1845.580001,
# day 82, sell 1 unit at price 172.669998,  total inventory 1.000000, investment 9.987893 %, total balance 2018.249999,
# day 86: buy 1 unit at price 173.970001, total inventory 2.000000, total balance 1844.279998
# day 88, sell 1 unit at price 174.539993,  total inventory 1.000000, investment 11.591323 %, total balance 2018.819991,
# day 92, sell 1 unit at price 170.570007,  total inventory 0.000000, investment -1.954356 %, total balance 2189.389998,
# day 96: buy 1 unit at price 172.259995, total inventory 1.000000, total balance 2017.130003
# day 98: buy 1 unit at price 173.029999, total inventory 2.000000, total balance 1844.100004
# day 100, sell 1 unit at price 174.350006,  total inventory 1.000000, investment 1.213289 %, total balance 2018.450010,
# day 102: buy 1 unit at price 174.289993, total inventory 2.000000, total balance 1844.160017
# day 104, sell 1 unit at price 177.089996,  total inventory 1.000000, investment 2.346412 %, total balance 2021.250013,
# day 108, sell 1 unit at price 178.460007,  total inventory 0.000000, investment 2.392572 %, total balance 2199.710020,
# day 116: buy 1 unit at price 167.429993, total inventory 1.000000, total balance 2032.280027
# day 118: buy 1 unit at price 160.500000, total inventory 2.000000, total balance 1871.780027
# day 120: buy 1 unit at price 163.029999, total inventory 3.000000, total balance 1708.750028
# day 122: buy 1 unit at price 155.149994, total inventory 4.000000, total balance 1553.600034
# day 124: buy 1 unit at price 162.710007, total inventory 5.000000, total balance 1390.890027
# day 126: buy 1 unit at price 167.369995, total inventory 6.000000, total balance 1223.520032
# day 128: buy 1 unit at price 172.429993, total inventory 7.000000, total balance 1051.090039
# day 130: buy 1 unit at price 171.070007, total inventory 8.000000, total balance 880.020032
# day 134, sell 1 unit at price 178.389999,  total inventory 7.000000, investment 6.546023 %, total balance 1058.410031,
# day 138, sell 1 unit at price 176.820007,  total inventory 6.000000, investment 10.168229 %, total balance 1235.230038,
# day 140: buy 1 unit at price 175.029999, total inventory 7.000000, total balance 1060.200039
# day 144, sell 1 unit at price 179.970001,  total inventory 6.000000, investment 10.390727 %, total balance 1240.170040,
# day 146, sell 1 unit at price 178.649994,  total inventory 5.000000, investment 15.146633 %, total balance 1418.820034,
# day 148, sell 1 unit at price 175.300003,  total inventory 4.000000, investment 7.737690 %, total balance 1594.120037,
# day 150, sell 1 unit at price 171.270004,  total inventory 3.000000, investment 2.330172 %, total balance 1765.390041,
# day 152, sell 1 unit at price 164.940002,  total inventory 2.000000, investment -4.343787 %, total balance 1930.330043,
# day 154: buy 1 unit at price 168.339996, total inventory 3.000000, total balance 1761.990047
# day 156: buy 1 unit at price 167.779999, total inventory 4.000000, total balance 1594.210048
# day 158: buy 1 unit at price 168.389999, total inventory 5.000000, total balance 1425.820049
# day 160: buy 1 unit at price 172.800003, total inventory 6.000000, total balance 1253.020046
# day 162: buy 1 unit at price 170.050003, total inventory 7.000000, total balance 1082.970043
# day 164: buy 1 unit at price 172.440002, total inventory 8.000000, total balance 910.530041
# day 166: buy 1 unit at price 174.729996, total inventory 9.000000, total balance 735.800045
# day 174: buy 1 unit at price 163.649994, total inventory 10.000000, total balance 572.150051
# day 176: buy 1 unit at price 162.320007, total inventory 11.000000, total balance 409.830044
# day 178: buy 1 unit at price 169.100006, total inventory 12.000000, total balance 240.730038
# day 180: buy 1 unit at price 176.889999, total inventory 13.000000, total balance 63.840039
# day 186, sell 1 unit at price 188.589996,  total inventory 12.000000, investment 10.241415 %, total balance 252.430035,
# day 188, sell 1 unit at price 186.440002,  total inventory 11.000000, investment 6.518884 %, total balance 438.870037,
# day 196, sell 1 unit at price 188.580002,  total inventory 10.000000, investment 12.023290 %, total balance 627.450039,
# day 198, sell 1 unit at price 187.500000,  total inventory 9.000000, investment 11.753487 %, total balance 814.950039,
# day 200, sell 1 unit at price 190.240005,  total inventory 8.000000, investment 12.975834 %, total balance 1005.190044,
# day 202, sell 1 unit at price 193.309998,  total inventory 7.000000, investment 11.869210 %, total balance 1198.500042,
# day 204, sell 1 unit at price 193.460007,  total inventory 6.000000, investment 13.766541 %, total balance 1391.960049,
# day 212: buy 1 unit at price 185.690002, total inventory 7.000000, total balance 1206.270047
# day 214: buy 1 unit at price 185.460007, total inventory 8.000000, total balance 1020.810040
# day 216: buy 1 unit at price 182.169998, total inventory 9.000000, total balance 838.640042
# day 218: buy 1 unit at price 184.160004, total inventory 10.000000, total balance 654.480038
# day 220: buy 1 unit at price 185.110001, total inventory 11.000000, total balance 469.370037
# day 222: buy 1 unit at price 183.919998, total inventory 12.000000, total balance 285.450039
# day 224: buy 1 unit at price 187.970001, total inventory 13.000000, total balance 97.480038
# day 242, sell 1 unit at price 201.500000,  total inventory 12.000000, investment 16.852237 %, total balance 298.980038,
# day 244: buy 1 unit at price 207.990005, total inventory 13.000000, total balance 90.990033
# day 248, sell 1 unit at price 208.880005,  total inventory 12.000000, investment 19.544446 %, total balance 299.870038,
# day 254, sell 1 unit at price 217.580002,  total inventory 11.000000, investment 32.954482 %, total balance 517.450040,
# day 256, sell 1 unit at price 215.039993,  total inventory 10.000000, investment 32.479044 %, total balance 732.490033,
# day 260, sell 1 unit at price 217.940002,  total inventory 9.000000, investment 28.882315 %, total balance 950.430035,
# day 262, sell 1 unit at price 222.979996,  total inventory 8.000000, investment 26.055739 %, total balance 1173.410031,
# day 264, sell 1 unit at price 227.630005,  total inventory 7.000000, investment 22.586032 %, total balance 1401.040036,
# day 266, sell 1 unit at price 226.869995,  total inventory 6.000000, investment 22.328258 %, total balance 1627.910031,
# day 268, sell 1 unit at price 221.300003,  total inventory 5.000000, investment 21.479939 %, total balance 1849.210034,
# day 272, sell 1 unit at price 226.410004,  total inventory 4.000000, investment 22.942006 %, total balance 2075.620038,
# day 274, sell 1 unit at price 217.880005,  total inventory 3.000000, investment 17.702989 %, total balance 2293.500043,
# day 276, sell 1 unit at price 218.369995,  total inventory 2.000000, investment 18.730969 %, total balance 2511.870038,
# day 278, sell 1 unit at price 217.660004,  total inventory 1.000000, investment 15.795075 %, total balance 2729.530042,
# day 280: buy 1 unit at price 222.190002, total inventory 2.000000, total balance 2507.340040
# day 282, sell 1 unit at price 224.949997,  total inventory 1.000000, investment 8.154234 %, total balance 2732.290037,
# day 284, sell 1 unit at price 227.259995,  total inventory 0.000000, investment 2.281828 %, total balance 2959.550032,
# day 300: buy 1 unit at price 222.729996, total inventory 1.000000, total balance 2736.820036
# day 302, sell 1 unit at price 219.800003,  total inventory 0.000000, investment -1.315491 %, total balance 2956.620039,
# day 316: buy 1 unit at price 186.800003, total inventory 1.000000, total balance 2769.820036
# day 318: buy 1 unit at price 193.529999, total inventory 2.000000, total balance 2576.290037
# day 320: buy 1 unit at price 176.979996, total inventory 3.000000, total balance 2399.310041
# day 322: buy 1 unit at price 172.289993, total inventory 4.000000, total balance 2227.020048
# day 324, sell 1 unit at price 174.240005,  total inventory 3.000000, investment -6.723768 %, total balance 2401.260053,
# day 326: buy 1 unit at price 179.550003, total inventory 4.000000, total balance 2221.710050
# day 328: buy 1 unit at price 184.820007, total inventory 5.000000, total balance 2036.890043
# day 330: buy 1 unit at price 174.720001, total inventory 6.000000, total balance 1862.170042
# day 336: buy 1 unit at price 165.479996, total inventory 7.000000, total balance 1696.690046
# day 338: buy 1 unit at price 166.070007, total inventory 8.000000, total balance 1530.620039
# day 340: buy 1 unit at price 156.830002, total inventory 9.000000, total balance 1373.790037
# day 342: buy 1 unit at price 146.830002, total inventory 10.000000, total balance 1226.960035
# day 344: buy 1 unit at price 156.149994, total inventory 11.000000, total balance 1070.810041
# day 346: buy 1 unit at price 157.740005, total inventory 12.000000, total balance 913.070036
# day 348: buy 1 unit at price 142.190002, total inventory 13.000000, total balance 770.880034
# day 350: buy 1 unit at price 147.929993, total inventory 14.000000, total balance 622.950041
# day 352: buy 1 unit at price 153.309998, total inventory 15.000000, total balance 469.640043
# day 354: buy 1 unit at price 152.289993, total inventory 16.000000, total balance 317.350050
# day 356: buy 1 unit at price 153.070007, total inventory 17.000000, total balance 164.280043
# day 358, sell 1 unit at price 155.860001,  total inventory 16.000000, investment -19.464682 %, total balance 320.140044,
# day 364: buy 1 unit at price 156.300003, total inventory 17.000000, total balance 163.840041
# day 368, sell 1 unit at price 166.520004,  total inventory 16.000000, investment -5.910268 %, total balance 330.360045,
# day 370: buy 1 unit at price 174.179993, total inventory 17.000000, total balance 156.180052
# day 380, sell 1 unit at price 172.029999,  total inventory 16.000000, investment -0.150905 %, total balance 328.210051,
# day 382: buy 1 unit at price 172.970001, total inventory 17.000000, total balance 155.240050
# day 384, sell 1 unit at price 174.330002,  total inventory 16.000000, investment -2.907269 %, total balance 329.570052,
# day 386: buy 1 unit at price 173.149994, total inventory 17.000000, total balance 156.420058
# day 388, sell 1 unit at price 175.850006,  total inventory 16.000000, investment -4.853371 %, total balance 332.270064,
# day 390: buy 1 unit at price 174.520004, total inventory 17.000000, total balance 157.750060
# day 394, sell 1 unit at price 180.910004,  total inventory 16.000000, investment 3.542813 %, total balance 338.660064,
# day 398: buy 1 unit at price 188.020004, total inventory 17.000000, total balance 150.640060
# day 402, sell 1 unit at price 191.050003,  total inventory 16.000000, investment 15.452023 %, total balance 341.690063,
# day 406, sell 1 unit at price 188.720001,  total inventory 15.000000, investment 13.638823 %, total balance 530.410064,
# day 410, sell 1 unit at price 195.350006,  total inventory 14.000000, investment 24.561629 %, total balance 725.760070,
# day 412, sell 1 unit at price 197.000000,  total inventory 13.000000, investment 34.168765 %, total balance 922.760070,
# day 414, sell 1 unit at price 199.500000,  total inventory 12.000000, investment 27.761772 %, total balance 1122.260070,
# day 418, sell 1 unit at price 199.229996,  total inventory 11.000000, investment 26.302770 %, total balance 1321.490066,
# day 422, sell 1 unit at price 204.529999,  total inventory 10.000000, investment 43.842743 %, total balance 1526.020065,
# day 424, sell 1 unit at price 207.160004,  total inventory 9.000000, investment 40.039217 %, total balance 1733.180069,
# day 426, sell 1 unit at price 204.300003,  total inventory 8.000000, investment 33.259413 %, total balance 1937.480072,
# day 430, sell 1 unit at price 209.149994,  total inventory 7.000000, investment 37.336663 %, total balance 2146.630066,
# day 432, sell 1 unit at price 208.479996,  total inventory 6.000000, investment 36.199116 %, total balance 2355.110062,
# day 436: buy 1 unit at price 197.179993, total inventory 7.000000, total balance 2157.930069
# day 440, sell 1 unit at price 190.080002,  total inventory 6.000000, investment 21.612283 %, total balance 2348.010071,
# day 442: buy 1 unit at price 183.089996, total inventory 7.000000, total balance 2164.920075
# day 444: buy 1 unit at price 182.779999, total inventory 8.000000, total balance 1982.140076
# day 446: buy 1 unit at price 178.970001, total inventory 9.000000, total balance 1803.170075
# day 448: buy 1 unit at price 177.380005, total inventory 10.000000, total balance 1625.790070
# day 450: buy 1 unit at price 175.070007, total inventory 11.000000, total balance 1450.720063
# day 452: buy 1 unit at price 179.639999, total inventory 12.000000, total balance 1271.080064
# day 454: buy 1 unit at price 185.220001, total inventory 13.000000, total balance 1085.860063
# day 456: buy 1 unit at price 192.580002, total inventory 14.000000, total balance 893.280061
# day 458: buy 1 unit at price 194.190002, total inventory 15.000000, total balance 699.090059
# day 464, sell 1 unit at price 199.460007,  total inventory 14.000000, investment 14.513730 %, total balance 898.550066,
# day 470, sell 1 unit at price 197.919998,  total inventory 13.000000, investment 14.424465 %, total balance 1096.470064,
# day 472, sell 1 unit at price 202.729996,  total inventory 12.000000, investment 17.083455 %, total balance 1299.200060,
# day 474, sell 1 unit at price 204.229996,  total inventory 11.000000, investment 17.023832 %, total balance 1503.430056,
# day 476, sell 1 unit at price 201.240005,  total inventory 10.000000, investment 7.031167 %, total balance 1704.670061,
# day 478, sell 1 unit at price 201.750000,  total inventory 9.000000, investment 2.317683 %, total balance 1906.420061,
# day 480, sell 1 unit at price 205.210007,  total inventory 8.000000, investment 12.081496 %, total balance 2111.630068,
# day 482, sell 1 unit at price 203.350006,  total inventory 7.000000, investment 11.253970 %, total balance 2314.980074,
# day 486, sell 1 unit at price 208.839996,  total inventory 6.000000, investment 16.689945 %, total balance 2523.820070,
# day 488, sell 1 unit at price 207.020004,  total inventory 5.000000, investment 16.709887 %, total balance 2730.840074,
# day 490, sell 1 unit at price 209.679993,  total inventory 4.000000, investment 19.769226 %, total balance 2940.520067,
# day 492, sell 1 unit at price 213.039993,  total inventory 3.000000, investment 18.592738 %, total balance 3153.560060,
# day 494, sell 1 unit at price 204.020004,  total inventory 2.000000, investment 10.150093 %, total balance 3357.580064,
# day 498, sell 1 unit at price 203.429993,  total inventory 1.000000, investment 5.634017 %, total balance 3561.010057,
# day 502, sell 1 unit at price 202.750000,  total inventory 0.000000, investment 4.408053 %, total balance 3763.760057,

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()
